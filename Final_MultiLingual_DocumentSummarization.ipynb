# %% [markdown]
# <a href="https://colab.research.google.com/github/ShrutiBobba/MultiLingual-Document-Summarization/blob/main/Final_MultiLingual_DocumentSummarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Install Dependencies**

# %%
# !pip install fasttext
# Out:
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pybind11>=2.2 (from fasttext)
#   Using cached pybind11-2.11.1-py3-none-any.whl (227 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext) (67.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasttext) (1.23.5)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4199772 sha256=50e3e495d0e38c88c6e6cd46822db32f97b4baefcf318432ceeb7e4878c1f6a1
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.2 pybind11-2.11.1

# %%
# !pip install stanza
# Out:
# Collecting stanza
#   Downloading stanza-1.6.1-py3-none-any.whl (881 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.2/881.2 kB 6.5 MB/s eta 0:00:00
# Collecting emoji (from stanza)
#   Downloading emoji-2.8.0-py2.py3-none-any.whl (358 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.9/358.9 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stanza) (1.23.5)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (3.20.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from stanza) (2.31.0)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (2.1.0+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stanza) (4.66.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3.0->stanza) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3.0->stanza) (1.3.0)
# Installing collected packages: emoji, stanza
# Successfully installed emoji-2.8.0 stanza-1.6.1

# %%
import os
import fasttext
import nltk
import sys
import stanza
import spacy
from nltk import ngrams

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('state_union')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package state_union to /root/nltk_data...
# [nltk_data]   Package state_union is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# ## **Read Data Files**

# %%
import sys

def read_file(filename):
    try:
        with open(filename, 'r') as file:
            data = file.read()
        return data
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
    except IOError as e:
        print(f"Error reading file '{filename}': {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    sys.exit(1)

# %%
import os
import sys

def read_all_files(path):
    file_texts = []
    try:
        for file_name in os.listdir(path):
            file_path = os.path.join(path, file_name)
            if os.path.isfile(file_path):
                with open(file_path, 'r') as file:
                    file_texts.append(file.read())
    except OSError as e:
        print(f"Error reading files in '{path}': {e}")
        sys.exit(1)
    return file_texts

# %%
file_texts = read_all_files("/content/drive/MyDrive/NLP/project/Data/Arabic")

# Check if there are at least two files before accessing their content
if len(file_texts) >= 2:
    print("Content of the first file:")
    print(file_texts[0])

    print("\nContent of the second file:")
    print(file_texts[1])
else:
    print("There are not enough files to display.")
# Out:
# Content of the first file:
# ذات مرة في قرية غريبة تقع بين التلال المتدحرجة ، عاشت هناك فتاة صغيرة تدعى ليلي. كانت تمتلك هدية غير عادية: القدرة على التواصل مع الحيوانات. كان أقرب أصدقائها بومة عجوز حكيمة تدعى أوليفر، شاركها معرفته بالغابة. في أحد الأيام هددت عاصفة رهيبة بإغراق القرية. عملت ليلي وأوليفر بلا كلل، وحشد الحيوانات للمساعدة في بناء الحواجز وإجلاء القرويين. ومع هطول الأمطار، أثمرت جهودهم، مما أنقذ القرية من الكارثة. اندهش القرويون من هبة ليلي، وأدركوا أهمية العيش في وئام مع الطبيعة. ومنذ ذلك اليوم، تعهدوا بحماية الغابة وجميع سكانها. أصبحت شجاعة ليلي وارتباطها بالحيوانات أسطورية، وتذكر الجميع أنه حتى الأصغر بيننا يمكن أن يحدث فرقًا كبيرًا. وهكذا ، في هذه القرية ، ازدهر الانسجام بين البشر والطبيعة ، وذلك بفضل الفتاة التي يمكن أن تتحدث إلى الحيوانات.
#
# Content of the second file:
# الطبيعة هي العالم الجميل من حولنا. ويشمل كل شيء في الخارج ، مثل الأشجار والجبال والأنهار والحيوانات. هناك العديد من أنواع الطبيعة المختلفة ، من الغابات الخضراء إلى الصحاري الساخنة والمحيطات العميقة. الطبيعة هي موطن لكثير من الحيوانات والنباتات ، وجميعهم يعملون معا للحفاظ على توازن الأشياء. تغني الطيور في السماء، وتعيش حيوانات مثل الغزلان والأرانب على الأرض، وتسبح الأسماك في الماء. انها مثل لغز كبير، وكل قطعة مهمة. الطبيعة تتغير أيضا على مدار السنة. في الربيع ، تتفتح الزهور ، وفي الخريف ، تتحول الأوراق إلى اللون. الطبيعة تعطينا الطعام لتناول الطعام، مثل الفواكه والخضروات، وهو مكان هادئ حيث يمكننا الاسترخاء والاستمتاع في الهواء الطلق. ولكن علينا أن نكون حذرين مع الطبيعة لأن الناس في بعض الأحيان يضر بها. نحن بحاجة إلى رعاية الطبيعة حتى تتمكن من البقاء جميلة وصحية بالنسبة لنا وللمستقبل.

# %%
file_texts = read_all_files("/content/drive/MyDrive/NLP/project/Data/English")

# Check if there are at least two files before accessing their content
if len(file_texts) >= 2:
    print("Content of the first file:")
    print(file_texts[0])

    print("\nContent of the second file:")
    print(file_texts[1])
else:
    print("There are not enough files to display.")
# Out:
# Content of the first file:
# Once upon a time in a quaint village nestled among rolling hills, there lived a young girl named Lily. She possessed an extraordinary gift: the ability to communicate with animals. Her closest friend was a wise old owl named Oliver, who shared his knowledge of the forest with her. One day, a terrible storm threatened to flood the village. Lily and Oliver worked tirelessly, rallying animals to help build barriers and evacuate villagers. As the rain poured, their efforts paid off, saving the village from disaster. The villagers were amazed by Lily's gift, and they realized the importance of living in harmony with nature. From that day forward, they vowed to protect the forest and all its inhabitants. Lily's courage and her bond with the animals became legendary, reminding everyone that even the smallest among us can make a big difference. And so, in this village, the harmony between humans and nature thrived, thanks to the girl who could speak to the animals.
#
# Content of the second file:
# Nature is the beautiful world around us. It includes everything outside, like trees, mountains, rivers, and animals. There are many different types of nature, from the green forests to the hot deserts and the deep oceans. Nature is home to many animals and plants, and they all work together to keep things in balance. Birds sing in the sky, animals like deer and rabbits live on the ground, and fish swim in the water. It's like a big puzzle, and every piece is important. Nature also changes throughout the year. In spring, flowers bloom, and in fall, leaves turn colorful. Nature gives us food to eat, like fruits and vegetables, and it's a peaceful place where we can relax and enjoy the outdoors. But we have to be careful with nature because sometimes people harm it. We need to take care of nature so it can stay beautiful and healthy for us and for the future.

# %% [markdown]
# ## **Remove Empty Lines**

# %%
def remove_empty_lines(text):
    lines = text.split('\n')
    non_empty_lines = [line for line in lines if line.strip()]
    return '\n'.join(non_empty_lines)

# %% [markdown]
# ## **Remove Stop Words**

# %%
def remove_stop_words(articles):
    return [' '.join([token for token in Lang_Model.word_tokenize(article) if token not in Lang_Model.stop_words() and token not in [',', '،']]) for article in articles]

# %%
articles_with_sw = file_texts
articles = remove_stop_words(file_texts)

# %%
#break into sentences with stop words
article_sentences_with_sw = [
    [sentence.strip() for sentence in Lang_Model.sent_tokenize(article)]
    for article in articles_with_sw
]
print(article_sentences_with_sw)
# Out:
# [['Once upon a time in a quaint village nestled among rolling hills, there lived a young girl named Lily.', 'She possessed an extraordinary gift: the ability to communicate with animals.', 'Her closest friend was a wise old owl named Oliver, who shared his knowledge of the forest with her.', 'One day, a terrible storm threatened to flood the village.', 'Lily and Oliver worked tirelessly, rallying animals to help build barriers and evacuate villagers.', 'As the rain poured, their efforts paid off, saving the village from disaster.', "The villagers were amazed by Lily's gift, and they realized the importance of living in harmony with nature.", 'From that day forward, they vowed to protect the forest and all its inhabitants.', "Lily's courage and her bond with the animals became legendary, reminding everyone that even the smallest among us can make a big difference.", 'And so, in this village, the harmony between humans and nature thrived, thanks to the girl who could speak to the animals.'], ['Nature is the beautiful world around us.', 'It includes everything outside, like trees, mountains, rivers, and animals.', 'There are many different types of nature, from the green forests to the hot deserts and the deep oceans.', 'Nature is home to many animals and plants, and they all work together to keep things in balance.', 'Birds sing in the sky, animals like deer and rabbits live on the ground, and fish swim in the water.', "It's like a big puzzle, and every piece is important.", 'Nature also changes throughout the year.', 'In spring, flowers bloom, and in fall, leaves turn colorful.', "Nature gives us food to eat, like fruits and vegetables, and it's a peaceful place where we can relax and enjoy the outdoors.", 'But we have to be careful with nature because sometimes people harm it.', 'We need to take care of nature so it can stay beautiful and healthy for us and for the future.']]

# %%
#break into sentences without stop words
article_sentences = [
    [sentence.strip() for sentence in Lang_Model.sent_tokenize(article)]
    for article in articles
]

article_sentences = [
    [
        ' '.join([token for token in Lang_Model.word_tokenize(sent) if token != '.'])
        for sent in article
    ]
    for article in article_sentences
]
print(article_sentences)
# Out:
# [['Once time quaint village nestled rolling hills lived young girl named Lily .', 'She possessed extraordinary gift : ability communicate animals .', 'Her closest friend wise owl named Oliver shared knowledge forest .', 'One day terrible storm threatened flood village .', 'Lily Oliver worked tirelessly rallying animals build barriers evacuate villagers .', 'As rain poured efforts paid saving village disaster .', "The villagers amazed Lily 's gift realized importance living harmony nature .", 'From day forward vowed protect forest inhabitants .', "Lily 's courage bond animals legendary reminding smallest make big difference .", 'And village harmony humans nature thrived girl speak animals .'], ['Nature beautiful world .', 'It includes trees mountains rivers animals .', 'There different types nature green forests hot deserts deep oceans .', 'Nature home animals plants work things balance .', 'Birds sing sky animals deer rabbits live ground fish swim water .', "It 's big puzzle piece important .", 'Nature changes year .', 'In spring flowers bloom fall leaves turn colorful .', "Nature food eat fruits vegetables 's peaceful place relax enjoy outdoors .", 'But careful nature harm .', 'We nature stay beautiful healthy future .']]

# %% [markdown]
# ## **Removing Punctuvations**

# %%
tmp_article_sentences = []
for article in article_sentences:
  tmp = []
  for sent in article:
    sent_tokens = Lang_Model.word_tokenize(sent)
    sent_tokens = [word for word in sent_tokens if word != '.']
    new_sent = ""
    for token in sent_tokens:
      new_sent += token + ' '
    tmp.append(new_sent)
  tmp_article_sentences.append(tmp)

article_sentences = tmp_article_sentences
article_sentences
# Out:
# [['Once time quaint village nestled rolling hills lived young girl named Lily ',
#   'She possessed extraordinary gift : ability communicate animals ',
#   'Her closest friend wise owl named Oliver shared knowledge forest ',
#   'One day terrible storm threatened flood village ',
#   'Lily Oliver worked tirelessly rallying animals build barriers evacuate villagers ',
#   'As rain poured efforts paid saving village disaster ',
#   "The villagers amazed Lily 's gift realized importance living harmony nature ",
#   'From day forward vowed protect forest inhabitants ',
#   "Lily 's courage bond animals legendary reminding smallest make big difference ",
#   'And village harmony humans nature thrived girl speak animals '],
#  ['Nature beautiful world ',
#   'It includes trees mountains rivers animals ',
#   'There different types nature green forests hot deserts deep oceans ',
#   'Nature home animals plants work things balance ',
#   'Birds sing sky animals deer rabbits live ground fish swim water ',
#   "It 's big puzzle piece important ",
#   'Nature changes year ',
#   'In spring flowers bloom fall leaves turn colorful ',
#   "Nature food eat fruits vegetables 's peaceful place relax enjoy outdoors ",
#   'But careful nature harm ',
#   'We nature stay beautiful healthy future ']]

# %% [markdown]
# ## **Detect Language**

# %%
model = fasttext.load_model('/content/drive/MyDrive/NLP/project/lid.176.ftz')
lang1 = model.predict(remove_new_lines(file_texts[0]), k=1)
lang2 = model.predict(remove_new_lines(file_texts[1]), k=1)
if lang1[0][0] == lang2[0][0]:
  if lang1[0][0] == '__label__en':
    print("English")
    Lang_Model = English_Language_Model()
  elif lang1[0][0] == '__label__ar':
    print("Arabic")
    Lang_Model = Arabic_Language_Model()
  else:
    print("Unknown language detected")
# Out:
# English
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %% [markdown]
# ##**English Language Model**

# %%
import nltk
import spacy
import stanza

class English_Language_Model:
    def word_tokenize(self, article):
        return nltk.word_tokenize(article)

    def stop_words(self):
        return nltk.corpus.stopwords.words()

    def sent_tokenize(self, article):
        return nltk.sent_tokenize(article)

    def lemmatization(self, text):
        nlp = stanza.Pipeline(lang='en', processors='tokenize,lemma')
        return [word.lemma for sent in nlp(text).sentences for word in sent.words]

    def pos_tagging(self, text):
        nlp = stanza.Pipeline(lang='en', processors='tokenize,pos')
        return [word.pos for sent in nlp(text).sentences for word in sent.words]

    def get_pos_importances(self, text):
        tag_importance = {'NOUN': 2, 'VERB': 1.9, 'ADV': 1.3, 'ADJ': 1.25}
        return [tag_importance.get(tag, 1) for tag in self.pos_tagging(text)]

    def get_ner_importance(self, text):
        ner_entities = set([word.text for word in spacy.load("en_core_web_sm")(text).ents])
        return [1.5 if word in ner_entities else 1 for word in self.word_tokenize(text)]

    def get_dependency_importance(self, text):
        return [1.1 + 0.1 * (token.head-1) for token in stanza.Pipeline(lang='en', processors='tokenize,mwt,pos,lemma,depparse')(text).sentences[0].words]

    def get_chunks_importance(self, text):
        chunkParser = nltk.RegexpParser(r"""Chunk: {<RB.?>*<VB.?>*<NNP>+<NN>?}""")
        chunked = chunkParser.parse(nltk.pos_tag(nltk.word_tokenize(text)))
        return [1.5 if subtree.label() == 'Chunk' else 1 for subtree in chunked.subtrees() for x in subtree]

# %% [markdown]
# ## **Arabic Language Model**

# %%
class ArabicLanguageModel:
    def word_tokenize(self, article):
        return nltk.tokenize.word_tokenize(article)

    def stop_words(self):
        return nltk.corpus.stopwords.words('arabic')

    def sent_tokenize(self, article):
        article = re.sub("؟", "?", article)
        return nltk.tokenize.sent_tokenize(article)

    def lemmatization(self, text):
        url = 'https://farasa.qcri.org/webapi/lemmatization/'
        api_key = "kusYKWEbCaQFtSumEA"
        payload = {'text': text, 'api_key': api_key}
        data = requests.post(url, data=payload)
        lemmas = json.loads(data.text)
        return lemmas['text']

    def pos_tagging(self, text):
        nlp = stanza.Pipeline(lang='ar', processors='tokenize,pos')
        doc = nlp(text)
        return [word.pos for sent in doc.sentences for word in sent.words]

    def get_pos_importances(self, text):
        pos_tags = self.pos_tagging(text)
        pos_importances = [2 if tag == 'NOUN' else 1.9 if tag == 'VERB' else 1.3 if tag == 'ADV' else 1.25 if tag == 'ADJ' else 1 for tag in pos_tags]
        return pos_importances

    def get_ner_importance(self, text):
        nlp = stanza.Pipeline(lang='ar', processors='tokenize,mwt,pos,lemma,depparse')
        doc = nlp(text)
        return [1 for _ in doc.sentences[0].words]

    def get_dependency_importance(self, text):
        nlp = stanza.Pipeline(lang='ar', processors='tokenize,mwt,pos,lemma,depparse')
        doc = nlp(text)
        return [1 for _ in doc.sentences[0].words]

    def get_chunks_importance(self, text):
        nlp = stanza.Pipeline(lang='ar', processors='tokenize,mwt,pos,lemma,depparse')
        doc = nlp(text)
        return [1 for _ in doc.sentences[0].words]

# %%
def get_lemmas(text):
  return Lang_Model.lemmatization(text)

# %%
def get_pos_tags(text):
  return Lang_Model.pos_tagging(text)

# %%
def get_pos_tags_importance(text):
  return Lang_Model.get_pos_importances(text)

# %%
def get_ner_importnace(text):
  return Lang_Model.get_ner_importnace(text)

# %%
def get_dependency_importnace(text):
  return Lang_Model.get_dependency_importnace(text)

# %%
def computeTf(lemmas, lemmas_total):
  fdist = nltk.FreqDist(lemmas)
  lemmas_Tf = {}
  for k, v in fdist.items():
    lemmas_Tf[k[0]] = v / lemmas_total
  return lemmas_Tf

# %%
def computeIdf(lemma, articles):
  N = len(articles)
  nidf = 0
  for article in articles:
      if (lemma in (get_lemmas(article))):
        nidf += 1
  result = math.log(N / nidf)
  return result

# %%
def get_chunks_importance(text):
  return Lang_Model.get_chunks_importance(text)

# %%
def get_lemmas_importance(articles):
  lemmas_importance = []
  for article in articles:
    lemmas_in_doc = get_lemmas(article)
    lemmas_total = len(lemmas_in_doc)
    lemma_doc = ""

    for lemma in lemmas_in_doc:
      lemma_doc += lemma + ' '
    lemmas = ngrams(lemma_doc.split(), 1)

    lemmas_Tf = computeTf(lemmas, lemmas_total)

    for lemma in lemmas:
      lemmas_Tf[lemma] *= computeIdf(lemma, articles)
    lemmas_importance.append(lemmas_Tf)

  return lemmas_importance

# %%
lemmas_importance = get_lemmas_importance(articles)
print(lemmas_importance[0])
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# {'once': 0.009708737864077669, 'time': 0.009708737864077669, 'quaint': 0.009708737864077669, 'village': 0.038834951456310676, 'nestle': 0.009708737864077669, 'roll': 0.009708737864077669, 'hill': 0.009708737864077669, 'live': 0.019417475728155338, 'young': 0.009708737864077669, 'girl': 0.019417475728155338, 'name': 0.019417475728155338, 'lily': 0.038834951456310676, '.': 0.0970873786407767, 'she': 0.009708737864077669, 'possess': 0.009708737864077669, 'extraordinary': 0.009708737864077669, 'gift': 0.019417475728155338, ':': 0.009708737864077669, 'ability': 0.009708737864077669, 'communicate': 0.009708737864077669, 'animal': 0.038834951456310676, 'her': 0.009708737864077669, 'close': 0.009708737864077669, 'friend': 0.009708737864077669, 'wise': 0.009708737864077669, 'owl': 0.009708737864077669, 'Oliver': 0.019417475728155338, 'share': 0.009708737864077669, 'knowledge': 0.009708737864077669, 'forest': 0.019417475728155338, 'one': 0.009708737864077669, 'day': 0.019417475728155338, 'terrible': 0.009708737864077669, 'storm': 0.009708737864077669, 'threaten': 0.009708737864077669, 'flood': 0.009708737864077669, 'work': 0.009708737864077669, 'tirelessly': 0.009708737864077669, 'rallying': 0.009708737864077669, 'build': 0.009708737864077669, 'barrier': 0.009708737864077669, 'evacuate': 0.009708737864077669, 'villager': 0.019417475728155338, 'as': 0.009708737864077669, 'rain': 0.009708737864077669, 'pour': 0.009708737864077669, 'effort': 0.009708737864077669, 'pay': 0.009708737864077669, 'save': 0.009708737864077669, 'disaster': 0.009708737864077669, 'the': 0.009708737864077669, 'amaze': 0.009708737864077669, "'s": 0.019417475728155338, 'realize': 0.009708737864077669, 'importance': 0.009708737864077669, 'harmony': 0.019417475728155338, 'nature': 0.019417475728155338, 'from': 0.009708737864077669, 'forward': 0.009708737864077669, 'vow': 0.009708737864077669, 'protect': 0.009708737864077669, 'inhabitant': 0.009708737864077669, 'courage': 0.009708737864077669, 'bond': 0.009708737864077669, 'legendary': 0.009708737864077669, 'remind': 0.009708737864077669, 'small': 0.009708737864077669, 'make': 0.009708737864077669, 'big': 0.009708737864077669, 'difference': 0.009708737864077669, 'and': 0.009708737864077669, 'human': 0.009708737864077669, 'thrived': 0.009708737864077669, 'speak': 0.009708737864077669}

# %% [markdown]
# ## **Calculate Sentence Importance**

# %%
def get_sent_importance(sent, article_num):
    lemmas = get_lemmas(sent)
    pos_importances = get_pos_tags_importance(sent)
    ner_importances = get_ner_importance(sent)
    dependency_importances = get_dependency_importance(sent)
    chunk_importances = get_chunks_importance(sent)
    print(sent, article_num)
    for lemma in lemmas:
        print(lemma)
    result = sum(
        [
            lemmas_importance[article_num].get(lemma, 0) * importance * ner_importance * chunk_importance
            for lemma in lemmas
            for importance in pos_importances
            for ner_importance in ner_importances
            for dependency_importance in dependency_importances
            for chunk_importance in chunk_importances
        ]
    )
    return result

# %%
article_lemma_sentences = []
article_sent_importance = []
index = 0
for article in article_sentences:
  article_lemma_sentences.append([])
  article_sent_importance.append([])
  for sent in article:
    lemmas = get_lemmas(sent)
    article_lemma_sentences[index].append(lemmas)
    s = get_sent_importance(sent, index)
    article_sent_importance[index].append(get_sent_importance(sent, index))
  index += 1
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | combined        |
# | pos       | combined_charlm |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# (S
#   Once/RB
#   time/NN
#   quaint/JJ
#   village/NN
#   nestled/VBD
#   rolling/VBG
#   hills/NNS
#   lived/VBD
#   young/JJ
#   girl/NN
#   named/VBN
#   Lily/RB)
# Once time quaint village nestled rolling hills lived young girl named Lily  0
# once
# time
# quaint
# village
# nestle
# roll
# hill
# live
# young
# girl
# name
# lily
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | combined        |
# | pos       | combined_charlm |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# (S
#   Once/RB
#   time/NN
#   quaint/JJ
#   village/NN
#   nestled/VBD
#   rolling/VBG
#   hills/NNS
#   lived/VBD
#   young/JJ
#   girl/NN
#   named/VBN
#   Lily/RB)
# Once time quaint village nestled rolling hills lived young girl named Lily  0
# once
# time
# quaint
# village
# nestle
# roll
# hill
# live
# young
# girl
# name
# lily
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | combined        |
# | pos       | combined_charlm |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# (S
#   She/PRP
#   possessed/VBD
#   extraordinary/JJ
#   gift/NN
#   :/:
#   ability/NN
#   communicate/NN
#   animals/NNS)
# She possessed extraordinary gift : ability communicate animals  0
# she
# possess
# extraordinary
# gift
# :
# ability
# communicate
# animal
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | combined        |
# | pos       | combined_charlm |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# (S
#   She/PRP
#   possessed/VBD
#   extraordinary/JJ
#   gift/NN
#   :/:
#   ability/NN
#   communicate/NN
#   animals/NNS)
# She possessed extraordinary gift : ability communicate animals  0
# she
# possess
# extraordinary
# gift
# :
# ability
# communicate
# animal
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | combined        |
# | pos       | combined_charlm |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# (S
#   Her/PRP$
#   closest/JJS
#   friend/NN
#   wise/NN
#   owl/NN
#   (Chunk named/VBN Oliver/NNP)
#   shared/VBD
#   knowledge/NN
#   forest/NN)
# Her closest friend wise owl named Oliver shared knowledge forest  0
# her
# close
# friend
# wise
# owl
# name
# Oliver
# share
# knowledge
# forest
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | combined        |
# | pos       | combined_charlm |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# (S
#   Her/PRP$
#   closest/JJS
#   friend/NN
#   wise/NN
#   owl/NN
#   (Chunk named/VBN Oliver/NNP)
#   shared/VBD
#   knowledge/NN
#   forest/NN)
# Her closest friend wise owl named Oliver shared knowledge forest  0
# her
# close
# friend
# wise
# owl
# name
# Oliver
# share
# knowledge
# forest
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | combined        |
# | pos       | combined_charlm |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# (S
#   One/CD
#   day/NN
#   terrible/JJ
#   storm/NN
#   threatened/VBD
#   flood/JJ
#   village/NN)
# One day terrible storm threatened flood village  0
# one
# day
# terrible
# storm
# threaten
# flood
# village
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | combined        |
# | pos       | combined_charlm |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# (S
#   One/CD
#   day/NN
#   terrible/JJ
#   storm/NN
#   threatened/VBD
#   flood/JJ
#   village/NN)
# One day terrible storm threatened flood village  0
# one
# day
# terrible
# storm
# threaten
# flood
# village
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | combined        |
# | pos       | combined_charlm |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# (S
#   (Chunk Lily/RB Oliver/NNP)
#   worked/VBD
#   tirelessly/RB
#   rallying/VBG
#   animals/NNS
#   build/VBP
#   barriers/NNS
#   evacuate/VBP
#   villagers/NNS)
# Lily Oliver worked tirelessly rallying animals build barriers evacuate villagers  0
# lily
# Oliver
# work
# tirelessly
# rallying
# animal
# build
# barrier
# evacuate
# villager
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | combined        |
# | pos       | combined_charlm |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# (S
#   (Chunk Lily/RB Oliver/NNP)
#   worked/VBD
#   tirelessly/RB
#   rallying/VBG
#   animals/NNS
#   build/VBP
#   barriers/NNS
#   evacuate/VBP
#   villagers/NNS)
# Lily Oliver worked tirelessly rallying animals build barriers evacuate villagers  0
# lily
# Oliver
# work
# tirelessly
# rallying
# animal
# build
# barrier
# evacuate
# villager
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | combined        |
# | pos       | combined_charlm |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# (S
#   As/IN
#   rain/NN
#   poured/VBD
#   efforts/NNS
#   paid/VBD
#   saving/VBG
#   village/NN
#   disaster/NN)
# As rain poured efforts paid saving village disaster  0
# as
# rain
# pour
# effort
# pay
# save
# village
# disaster
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | combined        |
# | pos       | combined_charlm |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# (S
#   As/IN
#   rain/NN
#   poured/VBD
#   efforts/NNS
#   paid/VBD
#   saving/VBG
#   village/NN
#   disaster/NN)
# As rain poured efforts paid saving village disaster  0
# as
# rain
# pour
# effort
# pay
# save
# village
# disaster
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | combined        |
# | pos       | combined_charlm |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# (S
#   The/DT
#   villagers/NNS
#   (Chunk amazed/VBD Lily/NNP)
#   's/POS
#   gift/NN
#   realized/VBD
#   importance/NN
#   living/NN
#   harmony/NN
#   nature/NN)
# The villagers amazed Lily 's gift realized importance living harmony nature  0
# the
# villager
# amaze
# lily
# 's
# gift
# realize
# importance
# live
# harmony
# nature
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | combined        |
# | pos       | combined_charlm |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# (S
#   The/DT
#   villagers/NNS
#   (Chunk amazed/VBD Lily/NNP)
#   's/POS
#   gift/NN
#   realized/VBD
#   importance/NN
#   living/NN
#   harmony/NN
#   nature/NN)
# The villagers amazed Lily 's gift realized importance living harmony nature  0
# the
# villager
# amaze
# lily
# 's
# gift
# realize
# importance
# live
# harmony
# nature
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | combined        |
# | pos       | combined_charlm |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# (S
#   From/IN
#   day/NN
#   forward/RB
#   vowed/VBD
#   protect/JJ
#   forest/JJS
#   inhabitants/NNS)
# From day forward vowed protect forest inhabitants  0
# from
# day
# forward
# vow
# protect
# forest
# inhabitant
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | combined        |
# | pos       | combined_charlm |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# (S
#   From/IN
#   day/NN
#   forward/RB
#   vowed/VBD
#   protect/JJ
#   forest/JJS
#   inhabitants/NNS)
# From day forward vowed protect forest inhabitants  0
# from
# day
# forward
# vow
# protect
# forest
# inhabitant
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# ...
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | combined        |
# | pos       | combined_charlm |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# (S
#   Nature/NN
#   food/NN
#   eat/NN
#   fruits/NNS
#   vegetables/VBP
#   's/POS
#   peaceful/JJ
#   place/NN
#   relax/NN
#   enjoy/NN
#   outdoors/NNS)
# Nature food eat fruits vegetables 's peaceful place relax enjoy outdoors  1
# Nature
# food
# eat
# fruit
# vegetable
# 's
# peaceful
# place
# relax
# enjoy
# outdoors
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | combined        |
# | pos       | combined_charlm |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# (S
#   Nature/NN
#   food/NN
#   eat/NN
#   fruits/NNS
#   vegetables/VBP
#   's/POS
#   peaceful/JJ
#   place/NN
#   relax/NN
#   enjoy/NN
#   outdoors/NNS)
# Nature food eat fruits vegetables 's peaceful place relax enjoy outdoors  1
# Nature
# food
# eat
# fruit
# vegetable
# 's
# peaceful
# place
# relax
# enjoy
# outdoors
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | combined        |
# | pos       | combined_charlm |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# (S But/CC careful/JJ nature/NN harm/NN)
# But careful nature harm  1
# but
# careful
# nature
# harm
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | combined        |
# | pos       | combined_charlm |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# (S But/CC careful/JJ nature/NN harm/NN)
# But careful nature harm  1
# but
# careful
# nature
# harm
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | combined        |
# | pos       | combined_charlm |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# (S We/PRP nature/VBP stay/JJ beautiful/JJ healthy/JJ future/NN)
# We nature stay beautiful healthy future  1
# we
# nature
# stay
# beautiful
# healthy
# future
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | lemma     | combined_nocharlm |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# INFO:stanza:Loading these models for language: en (English):
# ===============================
# | Processor | Package         |
# -------------------------------
# | tokenize  | combined        |
# | pos       | combined_charlm |
# ===============================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# WARNING:stanza:Can not find mwt: default from official model list. Ignoring it.
# INFO:stanza:Loading these models for language: en (English):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined          |
# | pos       | combined_charlm   |
# | lemma     | combined_nocharlm |
# | depparse  | combined_charlm   |
# =================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!
# (S We/PRP nature/VBP stay/JJ beautiful/JJ healthy/JJ future/NN)
# We nature stay beautiful healthy future  1
# we
# nature
# stay
# beautiful
# healthy
# future

# %%
print(lemmas_importance[0])
print(article_lemma_sentences[0][1])
print(articale_sent_importance[0][1])
# Out:
# {'once': 0.009708737864077669, 'time': 0.009708737864077669, 'quaint': 0.009708737864077669, 'village': 0.038834951456310676, 'nestle': 0.009708737864077669, 'roll': 0.009708737864077669, 'hill': 0.009708737864077669, 'live': 0.019417475728155338, 'young': 0.009708737864077669, 'girl': 0.019417475728155338, 'name': 0.019417475728155338, 'lily': 0.038834951456310676, '.': 0.0970873786407767, 'she': 0.009708737864077669, 'possess': 0.009708737864077669, 'extraordinary': 0.009708737864077669, 'gift': 0.019417475728155338, ':': 0.009708737864077669, 'ability': 0.009708737864077669, 'communicate': 0.009708737864077669, 'animal': 0.038834951456310676, 'her': 0.009708737864077669, 'close': 0.009708737864077669, 'friend': 0.009708737864077669, 'wise': 0.009708737864077669, 'owl': 0.009708737864077669, 'Oliver': 0.019417475728155338, 'share': 0.009708737864077669, 'knowledge': 0.009708737864077669, 'forest': 0.019417475728155338, 'one': 0.009708737864077669, 'day': 0.019417475728155338, 'terrible': 0.009708737864077669, 'storm': 0.009708737864077669, 'threaten': 0.009708737864077669, 'flood': 0.009708737864077669, 'work': 0.009708737864077669, 'tirelessly': 0.009708737864077669, 'rallying': 0.009708737864077669, 'build': 0.009708737864077669, 'barrier': 0.009708737864077669, 'evacuate': 0.009708737864077669, 'villager': 0.019417475728155338, 'as': 0.009708737864077669, 'rain': 0.009708737864077669, 'pour': 0.009708737864077669, 'effort': 0.009708737864077669, 'pay': 0.009708737864077669, 'save': 0.009708737864077669, 'disaster': 0.009708737864077669, 'the': 0.009708737864077669, 'amaze': 0.009708737864077669, "'s": 0.019417475728155338, 'realize': 0.009708737864077669, 'importance': 0.009708737864077669, 'harmony': 0.019417475728155338, 'nature': 0.019417475728155338, 'from': 0.009708737864077669, 'forward': 0.009708737864077669, 'vow': 0.009708737864077669, 'protect': 0.009708737864077669, 'inhabitant': 0.009708737864077669, 'courage': 0.009708737864077669, 'bond': 0.009708737864077669, 'legendary': 0.009708737864077669, 'remind': 0.009708737864077669, 'small': 0.009708737864077669, 'make': 0.009708737864077669, 'big': 0.009708737864077669, 'difference': 0.009708737864077669, 'and': 0.009708737864077669, 'human': 0.009708737864077669, 'thrived': 0.009708737864077669, 'speak': 0.009708737864077669}
# ['she', 'possess', 'extraordinary', 'gift', ':', 'ability', 'communicate', 'animal']
# 778.4388349515632

# %%
article_sentences = [
    [(article_sentences_with_sw[i][j], sent, article_sent_importance[i][j]) for j, sent in enumerate(article)]
    for i, article in enumerate(article_sentences)
]

# %% [markdown]
# ## **Summarization**

# %%
summarization_factor = 0.7

# %%
def sort_sentences(article):
    return sorted(article, key=lambda x: x[2], reverse=True)

# %%
def is_similar(lemma_sentence1, lemma_sentence2):
    lemmas1, lemmas2 = map(Lang_Model.word_tokenize, [lemma_sentence1, lemma_sentence2])

    common_lemmas = set(lemmas1) & set(lemmas2)
    similar_ratio = len(common_lemmas) / max(len(lemmas1), len(lemmas2))

    return similar_ratio > 0.8, max(lemma_sentence1, lemma_sentence2, key=len) if similar_ratio > 0.8 else ""

# %%
def get_k_sentences_in_article(summarization_factor, article):
    k = int(len(article) * summarization_factor)
    sorted_sentences = sort_sentences(article)
    selected_sentences = [sorted_sentences[0]]

    for sent in sorted_sentences[1:k]:
        is_unique = all(not is_similar(sent[1], y[1])[0] for y in selected_sentences)
        if is_unique:
            selected_sentences.append(sent)

    return selected_sentences, k

# %%
def get_k_sentences(summarization_factor, article_sentences):
    k_sentences = [get_k_sentences_in_article(summarization_factor, article)[0] for article in article_sentences]
    result = [k_sentences[0][0]]

    for i in range(1, max(map(len, k_sentences))):
        new_sent = True
        for sentences in k_sentences:
            if i < len(sentences):
                result.append(sentences[i])
                new_sent = False

        if new_sent:
            break

    return result

# %%
final_text = get_k_sentences(summarization_factor, article_sentences)

# %%
final_summary = ""
for test in final_text:
  final_summary += test[0] + '\n'

# %%
with open('/content/drive/MyDrive/NLP/project/summary.txt', 'w') as f:
    f.write(final_summary)

# %% [markdown]
# ## **LDA Approach**

# %%
import numpy as np
import math
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
def get_topics(articles=articles):
    doctopic = {i: {} for i in range(4)}
    topics_scores = np.zeros(4)
    models = []

    for article, article_with_sw in zip(articles, articles_with_sw):
        sentences = Lang_Model.sent_tokenize(article)
        cv_X = CountVectorizer(max_features=10000, ngram_range=(1, 2), max_df=0.98).fit_transform(sentences)
        lda = LatentDirichletAllocation(n_components=4).fit_transform(cv_X)
        models.append(lda)

    for model in models:
        topics_scores += np.sum(model, axis=0)

    for i, article_with_sw in enumerate(articles_with_sw):
        sentences = Lang_Model.sent_tokenize(article_with_sw)
        for j, sentence in enumerate(sentences):
            topic_index = np.argmax(models[i][j])
            doctopic[topic_index][sentence] = np.max(models[i][j])

    return doctopic, topics_scores

# %%
sent_topics,topics_scores=get_topics(articles)

# %%
def get_k_sentences_with_lda(summarization_factor, article_sentences, sent_topics, topics_scores):
    k_sentences = []
    final_sum = []
    lenn = 0
    old_k = 0

    for article in article_sentences:
        temp, temp_k = get_k_sentences_in_article(summarization_factor, article)
        k_sentences.append(temp)
        lenn += len(temp)
        old_k = max(temp_k, old_k)

    k = int(lenn * summarization_factor)

    num_sent_topics = [math.ceil(k * topic_score / np.sum(topics_scores)) for topic_score in topics_scores]

    for index in sent_topics:
        final_sum.append(sorted(sent_topics[index], reverse=True)[:num_sent_topics[index]])

    return final_sum

# %%
final_text_with_lda = get_k_sentences_with_lda(summarization_factor, article_sentences,sent_topics,topics_scores)

# %%
final_text_with_lda
# Out:
# [['Nature is the beautiful world around us.',
#   'In spring, flowers bloom, and in fall, leaves turn colorful.'],
#  ["The villagers were amazed by Lily's gift, and they realized the importance of living in harmony with nature.",
#   'She possessed an extraordinary gift: the ability to communicate with animals.',
#   'Once upon a time in a quaint village nestled among rolling hills, there lived a young girl named Lily.',
#   'Nature is home to many animals and plants, and they all work together to keep things in balance.',
#   'Nature also changes throughout the year.'],
#  ['There are many different types of nature, from the green forests to the hot deserts and the deep oceans.',
#   'One day, a terrible storm threatened to flood the village.'],
#  ["It's like a big puzzle, and every piece is important.",
#   'From that day forward, they vowed to protect the forest and all its inhabitants.']]

# %%
final_summary = ""
for test in final_text_with_lda:
  for t in test:
    final_summary += t + '\n'

# %%
with open('/content/drive/MyDrive/NLP/project/summary_with_lda.txt', 'w') as f:
    f.write(final_summary)
